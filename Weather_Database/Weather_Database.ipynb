# %%
## Deliverable 1
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# 3. Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# import the requests library
import requests

# import the API key
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 5. Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities - try-except block learning
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["main"]
        city_details = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_details
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | medicine hat
# Processing Record 2 of Set 1 | veraval
# Processing Record 3 of Set 1 | rumonge
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | pundaguitan
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | joshimath
# Processing Record 8 of Set 1 | alofi
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | mamlyutka
# Processing Record 13 of Set 1 | lorengau
# Processing Record 14 of Set 1 | san francisco
# Processing Record 15 of Set 1 | padang
# Processing Record 16 of Set 1 | olafsvik
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | salvador
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | lake charles
# Processing Record 25 of Set 1 | dapaong
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | hartford
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | hami
# Processing Record 31 of Set 1 | alice springs
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | ponta do sol
# Processing Record 34 of Set 1 | sao felix do xingu
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | bonavista
# Processing Record 38 of Set 1 | isangel
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | burnie
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | samfya
# Processing Record 43 of Set 1 | leh
# Processing Record 44 of Set 1 | puerto quijarro
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | kavaratti
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | muros
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | namwala
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | genhe
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | merauke
# Processing Record 7 of Set 2 | bembereke
# Processing Record 8 of Set 2 | buala
# Processing Record 9 of Set 2 | two hills
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | qui nhon
# Processing Record 12 of Set 2 | chicama
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | quatre cocos
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | benito juarez
# Processing Record 18 of Set 2 | taruma
# Processing Record 19 of Set 2 | havre-saint-pierre
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | vryburg
# Processing Record 22 of Set 2 | pangai
# Processing Record 23 of Set 2 | santa rosa
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | doha
# Processing Record 26 of Set 2 | linqing
# Processing Record 27 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 2 | vincennes
# Processing Record 29 of Set 2 | hualmay
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | beyneu
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | mukhen
# Processing Record 34 of Set 2 | bhanpuri
# Processing Record 35 of Set 2 | nizip
# Processing Record 36 of Set 2 | nantucket
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | nisia floresta
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | esperance
# Processing Record 42 of Set 2 | kurumkan
# Processing Record 43 of Set 2 | ushuaia
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | aykhal
# Processing Record 46 of Set 2 | havelock
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | shimoda
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | longyearbyen
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | acapulco
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | illapel
# Processing Record 8 of Set 3 | fort wellington
# Processing Record 9 of Set 3 | soyo
# Processing Record 10 of Set 3 | hasaki
# Processing Record 11 of Set 3 | mindelo
# Processing Record 12 of Set 3 | punta arenas
# Processing Record 13 of Set 3 | wajir
# Processing Record 14 of Set 3 | lobva
# Processing Record 15 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | klaksvik
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | sangar
# Processing Record 22 of Set 3 | flinders
# Processing Record 23 of Set 3 | constitucion
# Processing Record 24 of Set 3 | meulaboh
# Processing Record 25 of Set 3 | gorontalo
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | pangkalanbuun
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | rincon
# Processing Record 31 of Set 3 | mount isa
# Processing Record 32 of Set 3 | doctor juan manuel frutos
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | freeport
# Processing Record 35 of Set 3 | ciudad bolivar
# Processing Record 36 of Set 3 | konotop
# Processing Record 37 of Set 3 | challans
# Processing Record 38 of Set 3 | benjamin hill
# Processing Record 39 of Set 3 | caravelas
# Processing Record 40 of Set 3 | amahai
# Processing Record 41 of Set 3 | maturin
# Processing Record 42 of Set 3 | westport
# Processing Record 43 of Set 3 | ulaangom
# Processing Record 44 of Set 3 | puerto carreno
# Processing Record 45 of Set 3 | hovd
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | jaicos
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | khandyga
# Processing Record 50 of Set 3 | ostrovnoy
# Processing Record 1 of Set 4 | zhicheng
# Processing Record 2 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 4 | sedona
# Processing Record 4 of Set 4 | marzuq
# Processing Record 5 of Set 4 | jega
# Processing Record 6 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 4 | rovaniemi
# Processing Record 8 of Set 4 | plettenberg bay
# Processing Record 9 of Set 4 | terme
# Processing Record 10 of Set 4 | deer lake
# Processing Record 11 of Set 4 | morgan city
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | half moon bay
# Processing Record 14 of Set 4 | samarai
# Processing Record 15 of Set 4 | sidi bin nur
# Processing Record 16 of Set 4 | comodoro rivadavia
# Processing Record 17 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 4 | pouembout
# Processing Record 19 of Set 4 | college
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | buraydah
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | isla mujeres
# Processing Record 26 of Set 4 | batemans bay
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | kieta
# Processing Record 29 of Set 4 | gannan
# Processing Record 30 of Set 4 | belmonte
# Processing Record 31 of Set 4 | port hardy
# Processing Record 32 of Set 4 | dwarka
# Processing Record 33 of Set 4 | ratnagiri
# Processing Record 34 of Set 4 | sri aman
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | naini tal
# Processing Record 37 of Set 4 | nouadhibou
# Processing Record 38 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 4 | raudeberg
# Processing Record 40 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | tra vinh
# Processing Record 43 of Set 4 | manaure
# Processing Record 44 of Set 4 | danville
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | hervey bay
# Processing Record 49 of Set 4 | datong
# Processing Record 50 of Set 4 | susehri
# Processing Record 1 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 2 of Set 5 | mildura
# Processing Record 3 of Set 5 | shebalino
# Processing Record 4 of Set 5 | presidencia roque saenz pena
# Processing Record 5 of Set 5 | souillac
# Processing Record 6 of Set 5 | russell
# Processing Record 7 of Set 5 | barranca
# Processing Record 8 of Set 5 | koumac
# Processing Record 9 of Set 5 | faya
# Processing Record 10 of Set 5 | manakara
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | aripuana
# Processing Record 13 of Set 5 | limoux
# Processing Record 14 of Set 5 | jawhar
# Processing Record 15 of Set 5 | cody
# Processing Record 16 of Set 5 | mehamn
# Processing Record 17 of Set 5 | poso
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | the valley
# Processing Record 20 of Set 5 | broome
# Processing Record 21 of Set 5 | nuuk
# Processing Record 22 of Set 5 | acajutla
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | chokurdakh
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | coahuayana
# Processing Record 27 of Set 5 | falmouth
# Processing Record 28 of Set 5 | folkestone
# Processing Record 29 of Set 5 | laguna
# Processing Record 30 of Set 5 | vila franca do campo
# Processing Record 31 of Set 5 | kapiri mposhi
# Processing Record 32 of Set 5 | nauta
# Processing Record 33 of Set 5 | roma
# Processing Record 34 of Set 5 | galle
# Processing Record 35 of Set 5 | yablonovo
# Processing Record 36 of Set 5 | tazovskiy
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | sainte-anne-des-monts
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 41 of Set 5 | byron bay
# Processing Record 42 of Set 5 | peniche
# Processing Record 43 of Set 5 | yorosso
# Processing Record 44 of Set 5 | boa vista
# Processing Record 45 of Set 5 | vostok
# Processing Record 46 of Set 5 | port elizabeth
# Processing Record 47 of Set 5 | yarmolyntsi
# Processing Record 48 of Set 5 | bengkulu
# Processing Record 49 of Set 5 | abu samrah
# Processing Record 50 of Set 5 | teguise
# Processing Record 1 of Set 6 | puerto madryn
# Processing Record 2 of Set 6 | jamame
# Processing Record 3 of Set 6 | tasiilaq
# Processing Record 4 of Set 6 | charters towers
# Processing Record 5 of Set 6 | oussouye
# Processing Record 6 of Set 6 | maine-soroa
# Processing Record 7 of Set 6 | severodvinsk
# Processing Record 8 of Set 6 | chuy
# Processing Record 9 of Set 6 | victoria
# Processing Record 10 of Set 6 | tiksi
# Processing Record 11 of Set 6 | hilo
# Processing Record 12 of Set 6 | nouakchott
# Processing Record 13 of Set 6 | san juan
# Processing Record 14 of Set 6 | kaeo
# Processing Record 15 of Set 6 | anadyr
# Processing Record 16 of Set 6 | mon
# Processing Record 17 of Set 6 | superior
# Processing Record 18 of Set 6 | saint-philippe
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | fairbanks
# Processing Record 21 of Set 6 | dennery
# Processing Record 22 of Set 6 | waipawa
# Processing Record 23 of Set 6 | straldza
# City not found. Skipping...
# Processing Record 24 of Set 6 | saldanha
# Processing Record 25 of Set 6 | luganville
# Processing Record 26 of Set 6 | leningradskiy
# Processing Record 27 of Set 6 | buchanan
# Processing Record 28 of Set 6 | hithadhoo
# Processing Record 29 of Set 6 | pokhara
# Processing Record 30 of Set 6 | trairi
# Processing Record 31 of Set 6 | selaphum
# Processing Record 32 of Set 6 | tougue
# Processing Record 33 of Set 6 | churapcha
# Processing Record 34 of Set 6 | colac
# Processing Record 35 of Set 6 | lhokseumawe
# Processing Record 36 of Set 6 | chifeng
# Processing Record 37 of Set 6 | meghri
# Processing Record 38 of Set 6 | verkhoyansk
# Processing Record 39 of Set 6 | sibut
# Processing Record 40 of Set 6 | xining
# Processing Record 41 of Set 6 | whitehorse
# Processing Record 42 of Set 6 | yeniseysk
# Processing Record 43 of Set 6 | adre
# Processing Record 44 of Set 6 | lixourion
# Processing Record 45 of Set 6 | hamilton
# Processing Record 46 of Set 6 | sao joao da barra
# Processing Record 47 of Set 6 | bentiu
# Processing Record 48 of Set 6 | ternuvate
# Processing Record 49 of Set 6 | sola
# Processing Record 50 of Set 6 | buzim
# Processing Record 1 of Set 7 | savonlinna
# Processing Record 2 of Set 7 | touros
# Processing Record 3 of Set 7 | lagoa
# Processing Record 4 of Set 7 | puerto escondido
# Processing Record 5 of Set 7 | yarensk
# Processing Record 6 of Set 7 | bandarbeyla
# Processing Record 7 of Set 7 | haines junction
# Processing Record 8 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 9 of Set 7 | yar-sale
# Processing Record 10 of Set 7 | homer
# Processing Record 11 of Set 7 | ankang
# Processing Record 12 of Set 7 | avera
# Processing Record 13 of Set 7 | capitan bado
# Processing Record 14 of Set 7 | timbiqui
# Processing Record 15 of Set 7 | gore
# Processing Record 16 of Set 7 | kruisfontein
# Processing Record 17 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 7 | bequimao
# Processing Record 19 of Set 7 | puerto penasco
# Processing Record 20 of Set 7 | upernavik
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | torbay
# Processing Record 23 of Set 7 | asahikawa
# Processing Record 24 of Set 7 | lipin bor
# Processing Record 25 of Set 7 | salalah
# Processing Record 26 of Set 7 | paita
# Processing Record 27 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 7 | dalbandin
# Processing Record 29 of Set 7 | deputatskiy
# Processing Record 30 of Set 7 | tondano
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | dillon
# Processing Record 33 of Set 7 | ribeira grande
# Processing Record 34 of Set 7 | two rivers
# Processing Record 35 of Set 7 | pacific grove
# Processing Record 36 of Set 7 | aksarka
# Processing Record 37 of Set 7 | sao filipe
# Processing Record 38 of Set 7 | mechanicsville
# Processing Record 39 of Set 7 | dolores
# Processing Record 40 of Set 7 | axim
# Processing Record 41 of Set 7 | hoquiam
# Processing Record 42 of Set 7 | cheremukhovo
# Processing Record 43 of Set 7 | nikolskoye
# Processing Record 44 of Set 7 | vilyuysk
# Processing Record 45 of Set 7 | ancud
# Processing Record 46 of Set 7 | camacha
# Processing Record 47 of Set 7 | saint george
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | mikumi
# Processing Record 50 of Set 7 | honiara
# Processing Record 1 of Set 8 | mizpe ramon
# City not found. Skipping...
# Processing Record 2 of Set 8 | clyde river
# Processing Record 3 of Set 8 | nioro
# Processing Record 4 of Set 8 | kailua
# Processing Record 5 of Set 8 | emilio carranza
# Processing Record 6 of Set 8 | hobyo
# Processing Record 7 of Set 8 | paamiut
# Processing Record 8 of Set 8 | surt
# Processing Record 9 of Set 8 | brindisi
# Processing Record 10 of Set 8 | tual
# Processing Record 11 of Set 8 | tansen
# Processing Record 12 of Set 8 | lake havasu city
# Processing Record 13 of Set 8 | atyrau
# Processing Record 14 of Set 8 | praia
# Processing Record 15 of Set 8 | qaqortoq
# Processing Record 16 of Set 8 | poum
# Processing Record 17 of Set 8 | codrington
# Processing Record 18 of Set 8 | dongning
# Processing Record 19 of Set 8 | rapar
# Processing Record 20 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 8 | copiapo
# Processing Record 22 of Set 8 | beloha
# Processing Record 23 of Set 8 | pangnirtung
# Processing Record 24 of Set 8 | boddam
# Processing Record 25 of Set 8 | bristol
# Processing Record 26 of Set 8 | bilibino
# Processing Record 27 of Set 8 | olinda
# Processing Record 28 of Set 8 | rayadrug
# Processing Record 29 of Set 8 | saint-esteve
# Processing Record 30 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 8 | saint anthony
# Processing Record 32 of Set 8 | zinder
# Processing Record 33 of Set 8 | villazon
# Processing Record 34 of Set 8 | kadaya
# Processing Record 35 of Set 8 | usinsk
# Processing Record 36 of Set 8 | urucara
# Processing Record 37 of Set 8 | estelle
# Processing Record 38 of Set 8 | ocos
# Processing Record 39 of Set 8 | samarkand
# Processing Record 40 of Set 8 | bhimunipatnam
# Processing Record 41 of Set 8 | kavieng
# Processing Record 42 of Set 8 | seoul
# Processing Record 43 of Set 8 | solwezi
# Processing Record 44 of Set 8 | hirara
# Processing Record 45 of Set 8 | same
# Processing Record 46 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 8 | chornobay
# Processing Record 49 of Set 8 | kalmunai
# Processing Record 50 of Set 8 | yenotayevka
# Processing Record 1 of Set 9 | dali
# Processing Record 2 of Set 9 | roald
# Processing Record 3 of Set 9 | kirillov
# Processing Record 4 of Set 9 | alta gracia
# Processing Record 5 of Set 9 | east london
# Processing Record 6 of Set 9 | jashpurnagar
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | rapid valley
# Processing Record 9 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 9 | sorland
# Processing Record 11 of Set 9 | iranshahr
# Processing Record 12 of Set 9 | broken hill
# Processing Record 13 of Set 9 | mahebourg
# Processing Record 14 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 9 | nunkini
# Processing Record 16 of Set 9 | lang son
# Processing Record 17 of Set 9 | kingston
# Processing Record 18 of Set 9 | ugoofaaru
# Processing Record 19 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 9 | pudozh
# Processing Record 21 of Set 9 | aswan
# Processing Record 22 of Set 9 | pamanukan
# Processing Record 23 of Set 9 | emerald
# Processing Record 24 of Set 9 | georgiyevka
# Processing Record 25 of Set 9 | champerico
# Processing Record 26 of Set 9 | ullapool
# Processing Record 27 of Set 9 | yenagoa
# Processing Record 28 of Set 9 | ereymentau
# Processing Record 29 of Set 9 | bonthe
# Processing Record 30 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 31 of Set 9 | aketi
# Processing Record 32 of Set 9 | west bay
# Processing Record 33 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 9 | jieshi
# Processing Record 35 of Set 9 | union
# Processing Record 36 of Set 9 | rodrigues alves
# Processing Record 37 of Set 9 | cerrito
# Processing Record 38 of Set 9 | trojan
# Processing Record 39 of Set 9 | muktsar
# Processing Record 40 of Set 9 | lawton
# Processing Record 41 of Set 9 | sragen
# Processing Record 42 of Set 9 | ewa beach
# Processing Record 43 of Set 9 | thatta
# Processing Record 44 of Set 9 | alyangula
# Processing Record 45 of Set 9 | tipuani
# Processing Record 46 of Set 9 | ladovskaya balka
# Processing Record 47 of Set 9 | florence
# Processing Record 48 of Set 9 | nongan
# Processing Record 49 of Set 9 | saint-joseph
# Processing Record 50 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 10 | rio gallegos
# Processing Record 2 of Set 10 | sijunjung
# Processing Record 3 of Set 10 | ilulissat
# Processing Record 4 of Set 10 | tilichiki
# Processing Record 5 of Set 10 | antigonish
# Processing Record 6 of Set 10 | praia da vitoria
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | hoi an
# Processing Record 9 of Set 10 | landskrona
# Processing Record 10 of Set 10 | general roca
# Processing Record 11 of Set 10 | palana
# Processing Record 12 of Set 10 | naushki
# Processing Record 13 of Set 10 | puerto del rosario
# Processing Record 14 of Set 10 | grand gaube
# Processing Record 15 of Set 10 | whitianga
# Processing Record 16 of Set 10 | luanda
# Processing Record 17 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 10 | husavik
# Processing Record 19 of Set 10 | kayes
# Processing Record 20 of Set 10 | tabuk
# Processing Record 21 of Set 10 | geraldton
# Processing Record 22 of Set 10 | port blair
# Processing Record 23 of Set 10 | bilma
# Processing Record 24 of Set 10 | price
# Processing Record 25 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 26 of Set 10 | khurba
# Processing Record 27 of Set 10 | berbera
# Processing Record 28 of Set 10 | dawei
# Processing Record 29 of Set 10 | ouadda
# Processing Record 30 of Set 10 | irig
# Processing Record 31 of Set 10 | mezen
# Processing Record 32 of Set 10 | walvis bay
# Processing Record 33 of Set 10 | nelson bay
# Processing Record 34 of Set 10 | puri
# Processing Record 35 of Set 10 | tautira
# Processing Record 36 of Set 10 | umm lajj
# Processing Record 37 of Set 10 | kuryk
# Processing Record 38 of Set 10 | vokhtoga
# Processing Record 39 of Set 10 | sur
# Processing Record 40 of Set 10 | bubaque
# Processing Record 41 of Set 10 | mamontovka
# Processing Record 42 of Set 10 | sibolga
# Processing Record 43 of Set 10 | karratha
# Processing Record 44 of Set 10 | ndola
# Processing Record 45 of Set 10 | moree
# Processing Record 46 of Set 10 | turukhansk
# Processing Record 47 of Set 10 | wukari
# Processing Record 48 of Set 10 | san lorenzo
# Processing Record 49 of Set 10 | myitkyina
# Processing Record 50 of Set 10 | bathsheba
# Processing Record 1 of Set 11 | seabra
# Processing Record 2 of Set 11 | rawson
# Processing Record 3 of Set 11 | resistencia
# Processing Record 4 of Set 11 | pita
# Processing Record 5 of Set 11 | porto velho
# Processing Record 6 of Set 11 | douentza
# Processing Record 7 of Set 11 | moose factory
# Processing Record 8 of Set 11 | berdavan
# Processing Record 9 of Set 11 | fort nelson
# Processing Record 10 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 11 | kropotkin
# Processing Record 12 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 13 of Set 11 | taybad
# Processing Record 14 of Set 11 | svetlaya
# Processing Record 15 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 11 | port-cartier
# Processing Record 17 of Set 11 | mancio lima
# Processing Record 18 of Set 11 | shetpe
# Processing Record 19 of Set 11 | urengoy
# Processing Record 20 of Set 11 | weihai
# Processing Record 21 of Set 11 | tambacounda
# Processing Record 22 of Set 11 | bowen
# Processing Record 23 of Set 11 | kaputa
# Processing Record 24 of Set 11 | hay river
# Processing Record 25 of Set 11 | hannibal
# Processing Record 26 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 11 | nhulunbuy
# Processing Record 28 of Set 11 | mao
# Processing Record 29 of Set 11 | mount gambier
# Processing Record 30 of Set 11 | pimentel
# Processing Record 31 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 11 | atar
# Processing Record 33 of Set 11 | los llanos de aridane
# Processing Record 34 of Set 11 | sinjar
# Processing Record 35 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 36 of Set 11 | mayo
# Processing Record 37 of Set 11 | ebano
# City not found. Skipping...
# Processing Record 38 of Set 11 | uroteppa
# City not found. Skipping...
# Processing Record 39 of Set 11 | reconquista
# Processing Record 40 of Set 11 | san cristobal
# Processing Record 41 of Set 11 | manali
# Processing Record 42 of Set 11 | vrchlabi
# Processing Record 43 of Set 11 | nemuro
# Processing Record 44 of Set 11 | melfort
# Processing Record 45 of Set 11 | popondetta
# Processing Record 46 of Set 11 | richards bay
# Processing Record 47 of Set 11 | jalu
# Processing Record 48 of Set 11 | nanortalik
# Processing Record 49 of Set 11 | asau
# Processing Record 50 of Set 11 | san juan bautista
# Processing Record 1 of Set 12 | okhotsk
# Processing Record 2 of Set 12 | sao gabriel da cachoeira
# Processing Record 3 of Set 12 | lovozero
# Processing Record 4 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 5 of Set 12 | fukue
# Processing Record 6 of Set 12 | palmira
# Processing Record 7 of Set 12 | varhaug
# Processing Record 8 of Set 12 | luwuk
# Processing Record 9 of Set 12 | diego de almagro
# Processing Record 10 of Set 12 | alta floresta
# Processing Record 11 of Set 12 | wasilla
# Processing Record 12 of Set 12 | kibala
# Processing Record 13 of Set 12 | mega
# Processing Record 14 of Set 12 | tiangua
# Processing Record 15 of Set 12 | kasama
# Processing Record 16 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 12 | berlevag
# Processing Record 18 of Set 12 | ballstad
# City not found. Skipping...
# Processing Record 19 of Set 12 | zhuanghe
# Processing Record 20 of Set 12 | dmitriyevka
# Processing Record 21 of Set 12 | kabale
# Processing Record 22 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 12 | funadhoo
# Processing Record 25 of Set 12 | eureka
# Processing Record 26 of Set 12 | saint-leu
# Processing Record 27 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 12 | marsh harbour
# Processing Record 29 of Set 12 | kununurra
# Processing Record 30 of Set 12 | kirakira
# Processing Record 31 of Set 12 | harper
# Processing Record 32 of Set 12 | hinton
# Processing Record 33 of Set 12 | krasnorechenskiy
# Processing Record 34 of Set 12 | san quintin
# Processing Record 35 of Set 12 | kaka
# Processing Record 36 of Set 12 | aybak
# City not found. Skipping...
# Processing Record 37 of Set 12 | salinopolis
# Processing Record 38 of Set 12 | port lincoln
# Processing Record 39 of Set 12 | azuaga
# Processing Record 40 of Set 12 | abha
# Processing Record 41 of Set 12 | maniitsoq
# Processing Record 42 of Set 12 | benjamin constant
# Processing Record 43 of Set 12 | guerrero negro
# Processing Record 44 of Set 12 | kovdor
# Processing Record 45 of Set 12 | vodnyy
# Processing Record 46 of Set 12 | necochea
# Processing Record 47 of Set 12 | namibe
# Processing Record 48 of Set 12 | bosaso
# Processing Record 49 of Set 12 | vao
# Processing Record 50 of Set 12 | tashtagol
# Processing Record 1 of Set 13 | iquitos
# Processing Record 2 of Set 13 | meadow lake
# Processing Record 3 of Set 13 | bereda
# Processing Record 4 of Set 13 | sitka
# Processing Record 5 of Set 13 | sioux lookout
# Processing Record 6 of Set 13 | fuxin
# Processing Record 7 of Set 13 | whitehaven
# Processing Record 8 of Set 13 | dapitan
# Processing Record 9 of Set 13 | linxia
# Processing Record 10 of Set 13 | karpathos
# Processing Record 11 of Set 13 | verkhnetulomskiy
# Processing Record 12 of Set 13 | north bend
# Processing Record 13 of Set 13 | pochutla
# Processing Record 14 of Set 13 | proletarskiy
# Processing Record 15 of Set 13 | muncar
# Processing Record 16 of Set 13 | bolhrad
# Processing Record 17 of Set 13 | totness
# Processing Record 18 of Set 13 | lavrentiya
# Processing Record 19 of Set 13 | bossier city
# Processing Record 20 of Set 13 | salihorsk
# Processing Record 21 of Set 13 | cobija
# Processing Record 22 of Set 13 | makinsk
# Processing Record 23 of Set 13 | dong xoai
# Processing Record 24 of Set 13 | terneuzen
# Processing Record 25 of Set 13 | plast
# Processing Record 26 of Set 13 | wuning
# Processing Record 27 of Set 13 | smithers
# Processing Record 28 of Set 13 | ziro
# Processing Record 29 of Set 13 | orlik
# Processing Record 30 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 13 | xiangxiang
# Processing Record 32 of Set 13 | tabou
# Processing Record 33 of Set 13 | san
# Processing Record 34 of Set 13 | yizheng
# Processing Record 35 of Set 13 | belgrade
# Processing Record 36 of Set 13 | sovetskiy
# Processing Record 37 of Set 13 | cravo norte
# Processing Record 38 of Set 13 | haapiti
# Processing Record 39 of Set 13 | cayenne
# Processing Record 40 of Set 13 | kimbe
# Processing Record 41 of Set 13 | eyl
# Processing Record 42 of Set 13 | bull savanna
# Processing Record 43 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 13 | praya
# Processing Record 45 of Set 13 | kiskunhalas
# Processing Record 46 of Set 13 | upornaya
# Processing Record 47 of Set 13 | coxim
# Processing Record 48 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 13 | zlynka
# Processing Record 50 of Set 13 | san carlos
# Processing Record 1 of Set 14 | chancay
# Processing Record 2 of Set 14 | macia
# Processing Record 3 of Set 14 | huarmey
# Processing Record 4 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 5 of Set 14 | muroto
# Processing Record 6 of Set 14 | ardmore
# Processing Record 7 of Set 14 | kaspiysk
# Processing Record 8 of Set 14 | sechura
# Processing Record 9 of Set 14 | paredon
# Processing Record 10 of Set 14 | licheng
# Processing Record 11 of Set 14 | port hedland
# Processing Record 12 of Set 14 | atagay
# Processing Record 13 of Set 14 | alakurtti
# Processing Record 14 of Set 14 | akyab
# Processing Record 15 of Set 14 | dunedin
# Processing Record 16 of Set 14 | maunabo
# Processing Record 17 of Set 14 | ossora
# Processing Record 18 of Set 14 | agadez
# Processing Record 19 of Set 14 | ibanda
# Processing Record 20 of Set 14 | santa cruz
# Processing Record 21 of Set 14 | talaya
# Processing Record 22 of Set 14 | dongsheng
# Processing Record 23 of Set 14 | uusikaupunki
# Processing Record 24 of Set 14 | halifax
# Processing Record 25 of Set 14 | avenal
# Processing Record 26 of Set 14 | ibra
# Processing Record 27 of Set 14 | maravilha
# Processing Record 28 of Set 14 | klyuchi
# Processing Record 29 of Set 14 | villa constitucion
# Processing Record 30 of Set 14 | alliance
# Processing Record 31 of Set 14 | atasu
# Processing Record 32 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 14 | kulhudhuffushi
# Processing Record 34 of Set 14 | sesheke
# Processing Record 35 of Set 14 | imperia
# Processing Record 36 of Set 14 | okato
# Processing Record 37 of Set 14 | rosario
# Processing Record 38 of Set 14 | labytnangi
# Processing Record 39 of Set 14 | jumla
# Processing Record 40 of Set 14 | xiongzhou
# Processing Record 41 of Set 14 | aklavik
# Processing Record 42 of Set 14 | minab
# Processing Record 43 of Set 14 | monrovia
# Processing Record 44 of Set 14 | rioja
# Processing Record 45 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 14 | acari
# Processing Record 47 of Set 14 | biloela
# Processing Record 48 of Set 14 | prieska
# Processing Record 49 of Set 14 | silvan
# Processing Record 50 of Set 14 | concarneau
# Processing Record 1 of Set 15 | flin flon
# Processing Record 2 of Set 15 | la palma
# Processing Record 3 of Set 15 | tineo
# Processing Record 4 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 5 of Set 15 | nakajo
# City not found. Skipping...
# Processing Record 6 of Set 15 | saint-francois
# Processing Record 7 of Set 15 | port moresby
# Processing Record 8 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 9 of Set 15 | troitskoye
# Processing Record 10 of Set 15 | kathmandu
# Processing Record 11 of Set 15 | hun
# Processing Record 12 of Set 15 | srednekolymsk
# Processing Record 13 of Set 15 | ambon
# Processing Record 14 of Set 15 | nishihara
# Processing Record 15 of Set 15 | katherine
# Processing Record 16 of Set 15 | dhidhdhoo
# Processing Record 17 of Set 15 | qasigiannguit
# Processing Record 18 of Set 15 | aleksin
# Processing Record 19 of Set 15 | blagoyevo
# Processing Record 20 of Set 15 | lazaro cardenas
# Processing Record 21 of Set 15 | tamandare
# Processing Record 22 of Set 15 | neyshabur
# Processing Record 23 of Set 15 | selma
# Processing Record 24 of Set 15 | ola
# Processing Record 25 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 15 | am timan
# Processing Record 27 of Set 15 | tezu
# Processing Record 28 of Set 15 | vozhega
# Processing Record 29 of Set 15 | tornio
# Processing Record 30 of Set 15 | ixtapa
# Processing Record 31 of Set 15 | longview
# Processing Record 32 of Set 15 | high level
# Processing Record 33 of Set 15 | pilar
# Processing Record 34 of Set 15 | kargasok
# Processing Record 35 of Set 15 | lata
# Processing Record 36 of Set 15 | zeya
# Processing Record 37 of Set 15 | kahului
# Processing Record 38 of Set 15 | omboue
# Processing Record 39 of Set 15 | ulladulla
# Processing Record 40 of Set 15 | lumajang
# Processing Record 41 of Set 15 | bharatpur
# Processing Record 42 of Set 15 | betare oya
# Processing Record 43 of Set 15 | arman
# Processing Record 44 of Set 15 | jardim
# Processing Record 45 of Set 15 | achi
# Processing Record 46 of Set 15 | ahipara
# Processing Record 47 of Set 15 | uarini
# Processing Record 48 of Set 15 | traralgon
# Processing Record 49 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 15 | marquette
# Processing Record 1 of Set 16 | anchorage
# Processing Record 2 of Set 16 | beni mazar
# Processing Record 3 of Set 16 | yanam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Medicine Hat  50.0501 -110.6683     22.71        63         100
# 1       Veraval  20.9000   70.3667     77.68        81           0
# 2       Rumonge  -3.9736   29.4386     71.10        82          12
# 3        Atuona  -9.8000 -139.0333     78.98        78          69
# 4   Pundaguitan   6.3711  126.1689     82.42        70         100
# 5       Rikitea -23.1203 -134.9692     77.85        71          12
# 6     Joshimath  30.5667   79.5667     55.13        56          27
# 7         Alofi -19.0595 -169.9187     82.29        83          75
# 8        Castro -24.7911  -50.0119     61.56        97          11
# 9       Qaanaaq  77.4840  -69.3632     -2.07        93         100
#
#    Wind Speed Country                 Date       Description
# 0        1.01      CA  2022-04-14 01:00:26   overcast clouds
# 1       10.71      IN  2022-04-14 01:00:27         clear sky
# 2        5.50      BI  2022-04-14 01:00:28        few clouds
# 3       18.30      PF  2022-04-14 01:00:28        light rain
# 4        6.26      PH  2022-04-14 01:00:29   overcast clouds
# 5       18.34      PF  2022-04-14 01:00:29        light rain
# 6        6.38      IN  2022-04-14 01:00:30  scattered clouds
# 7        2.30      NU  2022-04-14 00:55:39     broken clouds
# 8        0.47      BR  2022-04-14 01:00:30        few clouds
# 9        5.99      GL  2022-04-14 01:00:31   overcast clouds

# %%
# Rearrange columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Medicine Hat      CA  2022-04-14 01:00:26  50.0501 -110.6683     22.71
# 1       Veraval      IN  2022-04-14 01:00:27  20.9000   70.3667     77.68
# 2       Rumonge      BI  2022-04-14 01:00:28  -3.9736   29.4386     71.10
# 3        Atuona      PF  2022-04-14 01:00:28  -9.8000 -139.0333     78.98
# 4   Pundaguitan      PH  2022-04-14 01:00:29   6.3711  126.1689     82.42
# 5       Rikitea      PF  2022-04-14 01:00:29 -23.1203 -134.9692     77.85
# 6     Joshimath      IN  2022-04-14 01:00:30  30.5667   79.5667     55.13
# 7         Alofi      NU  2022-04-14 00:55:39 -19.0595 -169.9187     82.29
# 8        Castro      BR  2022-04-14 01:00:30 -24.7911  -50.0119     61.56
# 9       Qaanaaq      GL  2022-04-14 01:00:31  77.4840  -69.3632     -2.07
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        63         100        1.01   overcast clouds
# 1        81           0       10.71         clear sky
# 2        82          12        5.50        few clouds
# 3        78          69       18.30        light rain
# 4        70         100        6.26   overcast clouds
# 5        71          12       18.34        light rain
# 6        56          27        6.38  scattered clouds
# 7        83          75        2.30     broken clouds
# 8        97          11        0.47        few clouds
# 9        93         100        5.99   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
